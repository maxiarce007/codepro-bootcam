# %%
letra1= input("ingrese la primera letra")
letra2= input("ingrese la segunda letra")

def comparar_letras(l1, l2):
    if l1 == l2:
        print("las letras son iguales")

    else:
        print("las letras no son iguales")

comparar_letras(letra1, letra2)
# Out:
# las letras no son iguales

# %%
letra= input('ingrese la primera palabra')
palabra_correcta= ('arbol')

def resolucion (x, y):
  for letra in palabra_correcta:
    if letra in palabra_correcta:
        print('palabra correcta')
    if letra in  'a''r' 'b''o':
        return ['a, r, b, o, es correcto'] 
    if letra in 'a''r''b':
            return ['a,r,b, es correcto']
    if letra in 'a''r''b':
         return ['a,r,b, es correcto']
    elif letra in "a"'r':
        return ["a,r, es correcto"]
    elif letra in "a":
        return['a, es correcto']
    else:
        return['palbra incorrecta, intente de nuevo']    



resolucion(letra, palabra_correcta)
# Out:
# palabra correcta
# ['a, r, b, o, es correcto']

# %%
palabra = input('escriba una palabra')
letr= "a"
def comparar
if letr in palabra:
    if

# %%
#return te devuelve el valor que ejecuto la funcion

def sumar(n1, n2):
    resultado_suma = n1 + n2
    return resultado_suma

resultado = sumar(5+5)

# %%
def retirar_dinero(dinero):
    return dinero

dinero_retirado = retirar_dinero(50000)
print(f'este es el dato de {dinero_retirado}')

sumar(dinero_retirado, 10000)

# %%
#crear una funcion con dos parametros con palabras y numeros
palabra = input ('escriba una palabra')
numero =  int(input('ingrese un numero'))
print(palabra, numero)
#que de un retorno y diferencie true de false
def resolucion(palabra, numero):
    if len(palabra) == numero:
        return True 
    else:
        return False
    
resolucion(palabra, numero)
# Out:
# hola 4
# True

# %%
#palabra_a_encontrar= input('escriba su palabra')

#lista_de_palabras= list(palabra_a_encontrar)

# palabra_a_ingresar= input('ingresar una palbra')
# palabras_ingresadas= [palabra_a_ingresar]
# lista_de_palabras= 
# print(palabras_ingresadas)

# Definir una variable palabra = input()
# Convertir palabra a lista con lista_de_palabra = list(palabra)
# Creamos otra lista llamada: palabras_ingresadas = []
# palabras_ingresadas.append(lista_de_palabra)
# Probar un bucle que repita 3 veces el proceso seguiente: 

# palabras_ingresadas = []
# for i in range(3):
#     palabra = input("Ingresar palabra")
#     lista_usuario = list(palabra)
#     palabras_ingresadas.append(lista_usuario)
#     print(palabras_ingresadas)
#     def dar_enter():
#      for i in palabras_ingresadas:
#         print(f'{i}')

# dar_enter()
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

# for i in lista:
#     if lista 
# lista=[['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

# def dar_enter():
#     for i in lista:
#         print(f"{i}\n")
# dar_enter()

# %%
#funcion verificadora
# palabra_secreta= ('salto')
# letras_verificadas= []
# cantidad_letras= 5
# #palabra_ingresada= 
# def verificardor_palabra(palabra_ingresada, palabra_secreta):
#     for i in range(palabra_ingresada):
#         las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta
#         la_letra_existe_en_la_palabra= palabra_ingresada[i] in palabra_secreta[i]

#         if las_palabras_son_iguales:
#             letras_verificadas.append(f'[{ palabra_ingresada[i]}]')
#         elif la_letra_existe_en_la_palabra:
#             letras_verificadas.append(f'({ palabra_ingresada[i]})')    
#         else:
#             letras_verificadas.append(f'{palabra_ingresada[i]}')

#     return letras_verificadas
# verificardor_palabra(palabra_secreta, palabra_ingresada)


# intentos= 0
# while intentos <= 6:
#     print(f'te quedan{6 - intentos}')
#     intentos = intentos + 1
#     palabra_ingresada = input('ingrese palabra')
#     print(f'la palabra ingresada es {palabra_ingresada}')
# Out:
#   Cell In[50], line 19
#     verificardor_palabra(palabra_ingresada, palabra_secreta=)
#                                                             ^
# SyntaxError: invalid syntax
