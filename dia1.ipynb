# %%
print('hola mundo')
# Out:
# hola mundo

# %%
# snake_case:
frase_famosa = 'hola mundo'
# orden de ejecucion:
fruta = 'naranja'
print(fruta)

# cantidad_de_frutas = 4
# print(cantidad_de_frutas)

fruta = 'banana'
print(fruta)
# Out:
# naranja
# banana

# %% [markdown]
# # tipos de datos

# %%
edad = 28  # integer
altura = 1.80 #float
nombre = "maggi" # string
feliz = True #bool

print( edad, altura, nombre, feliz)
# Out:
# 28 1.8 maggi True

# %%
nombre = 'Maximiliano Arce'
edad = 25
ciudad = 'luque'

print( 'hola soy ', nombre, ' tengo', edad, 'soy de', ciudad)
# Out:
# hola soy  Maximiliano Arce  tengo 25 soy de luque

# %% [markdown]
# <!-- # reglas para nombrar variables
# puede incluir leter, numeros y guiones
# deve empezar con letra y guion bajo, nunca con un numero
# evitar usar palabras reservadas de python
# usar nombres descripivos
#
# operadores aritmeticos
# + suma
# - resta
# * multiplicacion
# / divicion
# // divicion entero
# % RESTO -->

# %%
#challenge 2
cantidad_de_manzanas = 10
cantidad_de_naranjas = 5
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
frutas_vendidas = 5
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print( 'tenia', cantidad_de_frutas, 'frutas, de las que vendi', frutas_vendidas, ' y me sobraron', frutas_restantes)
# Out:
# tenia 15 frutas, de las que vendi 5  y me sobraron 10

# %%
nombre = 'maximiliano'
apellido = 'arce'

print(f'hola mi nombre es {nombre} {apellido}')
#tambien se pudes concatenar con {}
# Out:
# hola mi nombre es maximiliano arce

# %%
nombre = 'Katherine'
apellido = 'Varela'

print(f'El color favorito de {nombre} {apellido} es el morado')
# Out:
# El color favorito de Katherine Varela es el morado

# %%
nombre= input('escribe tu nombre')
print(f'esta persona se llama {nombre}')
# Out:
# esta persona se llama maxi

# %%
# eda = input(cuantos anhos tienes)
# print(type(edad))

edad = int( input('escribe tu edad'))
altura = float(input('escribe tu altura'))
# edadint = int(edad)
# alturafloot = float(altura)
print (f'esta persona tiene {edad} y mide {altura} y sumados dan {edad + altura}')
# Out:
# esta persona tiene 25 y mide 1.75 y sumados dan 26.75

# %%
# def hacer_la_cena():
#     print('lavar la olla')
#     print('cortar las verduras')
#     print('integrar los ingredientes a la olla')
#     print('cocinar por 45 min')
#     print('........................')

# hacer_la_cena()
# print(' ')
# hacer_la_cena()
# print(' ')
# hacer_la_cena()
color = str(input('elija color'))
talle = str(input('escoja su talle'))

def tipo_de_remera(color, talle):
     print('que color de remera desea?')
     print(f'quiero una remera de color {color}')
     print('de que talle?')
     print(f'del talle {talle}')
     input()

tipo_de_remera(color, talle)
# Out:
# que color de remera desea?
# quiero una remera de color rojo
# de que talle?
# del talle g

# %%
def comprar_un_auto(x, y):
    print(f'el modelo del auto que quiero es {x} y del color {y}')
    
    
comprar_un_auto( 'toyota', 'rojo')
# Out:
# el modelo del auto que quiero es toyota y del color rojo

# %%
def comprar_un_auto(articulo, tipo, color):
    print('que tipo de vehiculo desea')
    print('quiero un {articulo} del {tipo} y de {color}')
    
comprar_un_auto('auto grande', '4x4', 'negro')
# Out:
# que tipo de vehiculo desea
# quiero un {articulo} del {tipo} y de {color}
