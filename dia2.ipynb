# %%
def mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica):
    print(f"El elemento a comprar es {elemento}, y cuenta con las siguientes caracteristicas: {primera_caracteristica}, {segunda_caracteristica}, {tercera_caracteristica}")

def producto_a_comprar():
    elemento = input("Ingrese el elemento a comprar: ")
    primera_caracteristica = input("Ingrese una caracteristica del elemento a comprar: ")
    segunda_caracteristica = input("Ingrese otra caracteristica del elemento a comprar: ")
    tercera_caracteristica = input("Ingrese una ultima caracteristica del elemento a comprar: ")

    mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica)

producto_a_comprar()

# %%
pulgadas = input("¿Cuántas pulgadas es la television")
def preguntar():
    resolucion = input("¿Cuál es la resolución que tiene la TV")
    print(f"La TV tiene {pulgadas} pulgadas y una resolucion de {resolucion}")

preguntar()

# %%
print('hola')
# Out:
# hola

# %%
edad= 17
#primera condicion

if edad < 18:
    print('es menor de edad')
#segunda condicion
else:
    print('es mayor')
# Out:
# es menor de edad

# %%
#varias condiciones

edad_laboral= 17

if edad_laboral <= 18:
    print('menor de edad')
elif edad_laboral > 65:
    print('jubilado')
else:
    print('activo laboral')
# Out:
# menor de edad

# %%
#challenge operadores

#elif es si pero
edad= int(input('que edad tienes?'))

if edad < 18:
    print('juguito nomas')
elif edad < 21:
    print ('podes tomar pero no comprar')

else :
    print('hace lo que quieras')

# operadores logicos
# Out:
# podes tomar pero no comprar

# %%
# difino mi variable
temperatura= float(input('temperatura en grados celcius'))

print(f'la temperatura es de {temperatura} c')
# if -10=temperatura<=10:  tambien es valido
# if temperatura <=18 and temperatura >= -10
# identifico el primer parametro
if temperatura < -10:
    print('Ñamano mbae')

elif temperatura <= 18:
    print('fresquete')

elif temperatura <= 30:
    print('calor`i')

elif temperatura <= 45:
    print('hakuuuuu')

else :
    print('Ñamano mbae')
# Out:
# la temperatura es de 25.0 c
# calor`i

# %%
numero_a_adivinar= 20
numero_ingresado= 10

#while+condicion
while numero_ingresado != numero_a_adivinar:
    numero_ingresado = int(input('ingresar numero'))
    print(numero_ingresado)

#

# %%
numero_a_ingresar = 30

while True:
    numero_a_ingresar= int(input('ingresar un numero'))
    break
print('contrasena correcta')
# Out:
# contrasena correcta

# %%
#crear una variable que contenga una contrasena
contrasena_correcta = 2233
#preguntar al usuario la contrasena
while True:
    ingresar_contrasena = int(input('escriba su contrasena'))
    
    if ingresar_contrasena == contrasena_correcta:
        print('contrasena correcta')
        break
    else:
        print('contrasena incorrecta')
        break
#crear un bucle
#imprimir un msj de contrasena correcta
# Out:
# contrasena incorrecta
# contrasena incorrecta
# contrasena incorrecta
# contrasena correcta

# %%
# la computadora empiza desde el 0
lista_de_frutas = ['naranja', 'pera', 'manzana']

print(lista_de_frutas [1])
#remover un lugar
lista_de_frutas.pop(2)
# agregar un elemento
lista_de_frutas.append('kiwi')
# quitar un elemento
lista_de_frutas.remove('naranja')
#nos dice cuantos elementos hay en la lista
print(len(lista_de_frutas))
# Out:
# pera
# 2

# %%
#crear una lista
lista_de_colores = ['rojo', 'verde', 'azul', 'blanco', 'negro']
print(lista_de_colores)
print('-------------')

#modificar el sugundo elemento
lista_de_colores[1]= 'amarillo'
print(lista_de_colores)
print('-------------')
#eliminar el tercer elemeto
lista_de_colores.pop(2)
print(lista_de_colores)
print('-------------')              

lista_de_colores
# Out:
# ['rojo', 'verde', 'azul', 'blanco', 'negro']
# -------------
# ['rojo', 'amarillo', 'azul', 'blanco', 'negro']
# -------------
# ['rojo', 'amarillo', 'blanco', 'negro']
# -------------
# ['rojo', 'amarillo', 'blanco', 'negro']

# %%
#bucles interativos= for
# for i in range(5):
#     print('hola')

# for interador in range(5):
#     print(interador)
#escribir un integrador de rango 10
for i in range(10):
    #ultiplicar el integrador por 2
    print(i*2)

# %%
lista_de_marcas = ['toyota', 'audi', 'peugeot', 'ferrari', 'fiat']
print(len(lista_de_marcas))
# for marca in lista_de_marcas:
#     print(marca)

for marca in lista_de_marcas:
    if len(marca) >=6:
        print(marca)
# Out:
# 5
# toyota
# peugeot
# ferrari

# %%
#solicitar un msj
#buscar la letra o
#imprimir el msj

escriba_un_msj = str(input("escribe un msj"))
print(escriba_un_msj)
for i in escriba_un_msj:
    if i == 'o':
        print('se encontro la letra o')
# Out:
# oroscopo
# se encontro la letra o
# se encontro la letra o
# se encontro la letra o
# se encontro la letra o

# %%
#variables
palabra_secreta = "gordo"

#tipos de datos
datos_bool = True#booleanos
datos_integrados = 20 #integer
datos_flotantes = 3.5 #flotantes
datos_string = 'hola' #string

#concatenacion
Print(datos_string + datos_bool)
p
